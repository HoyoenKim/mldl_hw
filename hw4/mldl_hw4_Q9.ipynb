# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
root_dir = '/content/drive/MyDrive/mldl/hw4'

# %%
train = pd.read_csv(os.path.join(root_dir, 'train.csv'))

# %%
train.head(5)
# Out:
#        id        date  airline ch_code  num_code dep_time   from time_taken  \
# 0  UVYA93  2022-02-11   Indigo      6E      2106    03:00  Delhi    02h 10m
# 1  1Y6UUB  2022-02-11  AirAsia      I5       764    04:25  Delhi    10h 20m
# 2  J62B2K  2022-02-11  AirAsia      I5       764    04:25  Delhi    02h 10m
# 3  HW31QF  2022-02-11  AirAsia      I5       548    04:45  Delhi    02h 25m
# 4  AI4BTM  2022-02-11  AirAsia      I5       548    04:45  Delhi    14h 20m
#
#        stop arr_time         to    class  price
# 0  non-stop    05:10    Kolkata  economy   6270
# 1    1-stop    14:45  Bangalore  economy   7423
# 2  non-stop    06:35     Mumbai  economy   5956
# 3  non-stop    07:10    Kolkata  economy   6060
# 4    1-stop    19:05  Bangalore  economy  21343

# %%
test = pd.read_csv(os.path.join(root_dir, 'test.csv'))

# %%
test.head(5)
# Out:
#        id        date  airline ch_code  num_code dep_time       from  \
# 0  RB0IF4  2022-03-23   Indigo      6E      5376    00:10     Mumbai
# 1  VZE001  2022-03-23   Indigo      6E      5376    00:10     Mumbai
# 2  KBPR5E  2022-03-23   Indigo      6E      5376    00:10     Mumbai
# 3  P9XC55  2022-03-23  AirAsia      I5       722    00:30  Bangalore
# 4  SWZ04L  2022-03-23  AirAsia      I5       722    00:30  Bangalore
#
#   time_taken      stop arr_time      to    class
# 0    08h 50m    1-stop    09:00   Delhi  economy
# 1    07h 10m    1-stop    07:20   Delhi  economy
# 2    10h 20m    1-stop    10:30   Delhi  economy
# 3    02h 50m  non-stop    03:20   Delhi  economy
# 4    06h 05m    1-stop    06:35  Mumbai  economy

# %%
submission = pd.read_csv(os.path.join(root_dir, 'submission.csv'))

# %%
submission.head(5)
# Out:
#        id        price
# 0  RB0IF4  3446.206897
# 1  VZE001  3359.137931
# 2  KBPR5E  3901.310345
# 3  P9XC55  4498.000000
# 4  SWZ04L  2203.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import mean_absolute_percentage_error

# %%
features = ['airline', 'ch_code', 'num_code', 'dep_time', 'from', 'time_taken', 'stop', 'to', 'class']
X = train[features]
X = pd.get_dummies(X)
y = train['price']

model = DecisionTreeRegressor(random_state=42)
model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=42)

# %%
X_test = test[features]
X_test = pd.get_dummies(X_test)
X_test = X_test.reindex(columns=X.columns, fill_value=0)

y_pred = model.predict(X_test)
submission = pd.DataFrame({'id': test['id'], 'price': y_pred})
submission.to_csv(os.path.join(root_dir, 'submission.csv'), index=False)
